# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 29.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# importing module
from pymongo import MongoClient

hostname = "mpy90m.h.filess.io"
database = "mongodbolst_givenswing"
port = "27018"
username = "mongodbolst_givenswing"
password = "1f6982c536993d75b21d1756320497b8aa612662"

uri = "mongodb://" + username + ":" + password + "@" + hostname + ":" + port + "/" + database

# Connect with the portnumber and host
client = MongoClient(uri)

# Access database
mydatabase = client[database]

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv('/Workspace/Users/adeebraja931@gmail.com/Drafts/product_category_name_translation.csv')

# Convert DataFrame to dictionary records
records = df.to_dict(orient='records')

# Insert records into MongoDB collection
mydatabase['product_category_name_translation'].insert_many(records)
# Out:
# InsertManyResult([ObjectId('6a4a7fe94eea11b65df7dd6e'), ObjectId('6a4a7fe94eea11b65df7dd6f'), ObjectId('6a4a7fe94eea11b65df7dd70'), ObjectId('6a4a7fe94eea11b65df7dd71'), ObjectId('6a4a7fe94eea11b65df7dd72'), ObjectId('6a4a7fe94eea11b65df7dd73'), ObjectId('6a4a7fe94eea11b65df7dd74'), ObjectId('6a4a7fe94eea11b65df7dd75'), ObjectId('6a4a7fe94eea11b65df7dd76'), ObjectId('6a4a7fe94eea11b65df7dd77'), ObjectId('6a4a7fe94eea11b65df7dd78'), ObjectId('6a4a7fe94eea11b65df7dd79'), ObjectId('6a4a7fe94eea11b65df7dd7a'), ObjectId('6a4a7fe94eea11b65df7dd7b'), ObjectId('6a4a7fe94eea11b65df7dd7c'), ObjectId('6a4a7fe94eea11b65df7dd7d'), ObjectId('6a4a7fe94eea11b65df7dd7e'), ObjectId('6a4a7fe94eea11b65df7dd7f'), ObjectId('6a4a7fe94eea11b65df7dd80'), ObjectId('6a4a7fe94eea11b65df7dd81'), ObjectId('6a4a7fe94eea11b65df7dd82'), ObjectId('6a4a7fe94eea11b65df7dd83'), ObjectId('6a4a7fe94eea11b65df7dd84'), ObjectId('6a4a7fe94eea11b65df7dd85'), ObjectId('6a4a7fe94eea11b65df7dd86'), ObjectId('6a4a7fe94eea11b65df7
# ...
